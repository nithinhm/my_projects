# %%
from bs4 import BeautifulSoup

# %%
with open('check.html', encoding='utf8') as file:
    contents = file.read()

# %%
soup = BeautifulSoup(contents, 'lxml')

print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    "D:\my_projects\trial for marks\venv\Scripts\python.exe" "D:\my_projects\trial for marks\main.py"
#   </p>
#   <title>
#    VTU Result 2023
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta name="google" value="notranslate"/>
#   <meta content="60;url=https://results.vtu.ac.in/" http-equiv="refresh"/>
#   <link href="../images/favicon.ico" rel="shortcut icon"/>
#   <link href="../css/style.css" rel="stylesheet"/>
#   <link href="../css/css/bootstrap.min.css" rel="stylesheet"/>
#   <script src="../js/js/jquery.min.js">
#   </script>
#   <script src="../js/js/bootstrap.min.js">
#   </script>
#   <script src="js/jquery.placeholder.label.js" type="text/javascript">
#   </script>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700" rel="stylesheet" type="text/css"/>
#   <link href="css/bootstrap1.min.css" rel="stylesheet"/>
# ...
